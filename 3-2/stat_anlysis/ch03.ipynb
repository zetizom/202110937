# %%
import numpy as np;
import pandas as pd;

# %precision 3
# Out:
# '%.3f'

# %%
df = pd.read_csv('../stat_anlysis/data/ch2_scores_em.csv', 
                 index_col = 'student number')

# %%
en_scores = np.array(df['english'])[:10]
ma_scores = np.array(df['mathematics'])[:10]

scores_df = pd.DataFrame({'english':en_scores,
                          'mathematics':ma_scores},
                         index= pd.Index(['A', 'B', 'C', 'D', 'E',
                                         'F', 'G', 'H', 'I', 'J'],
                                        name='student'))
scores_df
# Out:
#          english  mathematics
# student
# A             42           65
# B             69           80
# C             56           63
# D             41           63
# E             57           76
# F             48           60
# G             65           81
# H             49           66
# I             65           78
# J             58           82

# %%
# 두 데이터 사이의 관계를 나타네는 지표, 공분산 
# 공분산은 세로축, 가로축이 다르기 때문에 직사각형(별표)이 될 수 있고 음의 면적(별표)이 될 수 있다.
# 한쪽 편차가 양, 반대 편차가 음이면 음의 면적이 된다.(별표)
#부호를 붙인 면적(별표)의 관점으로 본다면 , 공분산이 0에 가까우면 무상관(별표)
# =\의 기능은?


summary_df = scores_df.copy()
summary_df['english_deviation'] =\
    summary_df['english'] - summary_df['english'].mean()
summary_df['mathematics_deviation'] =\
    summary_df['mathematics'] - summary_df['mathematics'].mean()
summary_df['product of deviation'] =\
    summary_df['english_deviation'] * summary_df['mathematics_deviation']

summary_df
# Out:
#          english  mathematics  english_deviation  mathematics_deviation  \
# student
# A             42           65              -13.0                   -6.4
# B             69           80               14.0                    8.6
# C             56           63                1.0                   -8.4
# D             41           63              -14.0                   -8.4
# E             57           76                2.0                    4.6
# F             48           60               -7.0                  -11.4
# G             65           81               10.0                    9.6
# H             49           66               -6.0                   -5.4
# I             65           78               10.0                    6.6
# J             58           82                3.0                   10.6
#
#          product of deviation
# student
# A                        83.2
# B                       120.4
# C                        -8.4
# D                       117.6
# ...

# %%
summary_df['product of deviation'].mean()
# Out:
# 62.800

# %%
cov_mat = np.cov(en_scores, ma_scores, ddof=0) 
cov_mat

# ddof를 함으로써 공분산의 모집합을 N으로 1로 하면 N-1이 모집합
# Out:
# array([[86.  , 62.8 ],
#        [62.8 , 68.44]])

# %%
cov_mat[0,0], cov_mat[1,1] 
# 각각 영어 수학 분산
# Out:
# (86.000, 68.440)

# %%
np.var(en_scores, ddof=0), np.var(ma_scores, ddof = 0) # np를 이용한 공분산 구하는 법
# Out:
# (86.000, 68.440)

# %%
cov_mat[0, 1], cov_mat[1,0]
# 이방식은 영어 수학 공분산
# Out:
# (62.800, 62.800)

# %%
np.cov(en_scores, ma_scores, ddof=0)[0,1] /\
(np.std(en_scores) * np.std(ma_scores))
# 상관 계수 계산
# Out:
# 0.819

# %%
np.corrcoef(en_scores, ma_scores) # 영어 수학의 상관계수를 행렬 혈태로 표현
# Out:
# array([[1.   , 0.819],
#        [0.819, 1.   ]])

# %%
scores_df.corr() # 표로 구현
# Out:
#               english  mathematics
# english      1.000000     0.818569
# mathematics  0.818569     1.000000

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
english_scores = np.array(df['english'])
math_scores = np.array(df['mathematics'])

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)

ax.scatter(english_scores, math_scores)
ax.set_xlabel('english')
ax.set_ylabel('mathematics')

plt.show()

# 이 산점도로 수학, 영어점수의 분포를 나타냄

# %%
poly_fit = np.polyfit(english_scores, math_scores, 1)
poly_1d = np.poly1d(poly_fit)

xs = np.linspace(english_scores.min(), english_scores.max())
ys = poly_1d(xs)

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.set_xlabel('english')
ax.set_ylabel('mathematics')

ax.scatter(english_scores, math_scores, label = 'score')
ax.plot(xs, ys, color='gray',
        label= f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x')

ax.legend(loc='upper left')

plt.show()
#회귀 직선을 통해서 어디부분에 데이터가 몰려 있는지 알 수 있다.

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)

c = ax.hist2d(english_scores, math_scores,
              bins=[9,8], range=[(35, 80), (55, 95)])
ax.set_xlabel('english')
ax.set_ylabel('mathematics')
ax.set_xticks(c[1])
ax.set_yticks(c[2])

fig.colorbar(c[3], ax = ax)
plt.show()

# 어느 점수 대에 학생들이 많이 몰려 있는지 확인 가능해짐

# %%
anscombe_data = np.load('../stat_anlysis/data/ch3_anscombe.npy')
print(anscombe_data.shape)
anscombe_data[0]
# npy 데이터도 읽어 오기 가능
# Out:
# (4, 11, 2)
# array([[10.  ,  8.04],
#        [ 8.  ,  6.95],
#        [13.  ,  7.58],
#        [ 9.  ,  8.81],
#        [11.  ,  8.33],
#        [14.  ,  9.96],
#        [ 6.  ,  7.24],
#        [ 4.  ,  4.26],
#        [12.  , 10.84],
#        [ 7.  ,  4.82],
#        [ 5.  ,  5.68]])

# %%
stats_df = pd.DataFrame(index=['X_mean', 'X_variance', 'Y_mean',
                               'Y_variance', 'X&Y_correlation',
                               'X&Y_regression line'])
for i, data in enumerate(anscombe_data):
    dataX = data[:, 0]
    dataY = data[:, 1]
    poly_fit = np.polyfit(dataX, dataY, 1)
    stats_df[f'data{i+1}'] =\
        [f'{np.mean(dataX):2f}',
         f'{np.var(dataX):2f}',
         f'{np.mean(dataY):2f}',   
         f'{np.var(dataY):2f}',    
         f'{np.corrcoef(dataX, dataY)[0, 1]:2f}',
         f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x']
stats_df

# 이런식으로 표로 표현하면 어떤 데이터인지 잘 이해가 안됨
# Out:
#                           data1       data2       data3       data4
# X_mean                 9.000000    9.000000    9.000000    9.000000
# X_variance            10.000000   10.000000   10.000000   10.000000
# Y_mean                 7.500909    7.500909    7.500000    7.500909
# Y_variance             3.752063    3.752390    3.747836    3.748408
# X&Y_correlation        0.816421    0.816237    0.816287    0.816521
# X&Y_regression line  3.00+0.50x  3.00+0.50x  3.00+0.50x  3.00+0.50x

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10, 10),
                         sharex=True, sharey=True)

xs = np.linspace(0, 30, 100)
for i, data in enumerate(anscombe_data):
    poly_fit = np.polyfit(data[:,0], data[:,1], 1)
    poly_1d = np.poly1d(poly_fit)
    ys = poly_1d(xs)

    ax = axes[i//2, i%2]
    ax.set_xlim([4, 20])
    ax.set_ylim([3, 13])

    ax.set_title(f'data{1+i}')
    ax.scatter(data[:,0], data[:,1])
    ax.plot(xs, ys, color='gray')



plt.tight_layout()
plt.show()

# 하지만 이처럼 각각의 데이터를 분포로 표현하면 얼마나 데이터들간의 차이가 있는지 파악할 수 있음
